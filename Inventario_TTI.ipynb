# %% [markdown]
# <a href="https://colab.research.google.com/github/Evelyn199627/EERR/blob/main/Inventario_TTI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/Inventario TTI - python.xlsx")

# %%
df.head()
# Out:
#   Articulo Solaut    Articulo TTI                                 Descripcion  \
# 0             1000        ACW 1000   ESCOBILLAS 6X6X15
# 1             1001        ACW 1001    ESCOBILLAS 8,8X10X16 (PRECIO POR UNIDAD
# 2             1002        ACW 1002                        ESCOBILLAS 8,X14X20
# 3             8080  MCX 4932367168   4932430148 MECHA BROCA UNIDRE 4 X 85
# 4             8087   MCX 493239939   4932430157 MECHA BROCA UNIDRE 7X100
#
#    Valor Fob U$S  Costo Standard  Unitario en $  \
# 0       0.760000                     1539.00000
# 1       1.480000                     2997.00000
# 2       2.010000                     4070.25000
# 3       0.937637                     1898.71397
# 4       1.078786                     2184.54188
#
#    Stock Inicial 26/04   CON AJUSTES INVENTARIO    INGRESOS TTI  SOLAUT  \
# 0                                           160.0           NaN     NaN
# 1                                           175.0           NaN     NaN
# ...

# %%
df.columns
# Out:
# Index(['Articulo Solaut ', 'Articulo TTI ', 'Descripcion', 'Valor Fob U$S',
#        'Costo Standard  Unitario en $',
#        'Stock Inicial 26/04   CON AJUSTES INVENTARIO  ', 'INGRESOS TTI',
#        'SOLAUT', 'SERVICIO TECNICO', 'BONIFICACION'],
#       dtype='object')

# %%
df_Inventario = pd.read_excel("/content/Inventario TTI.xlsx")

# %%
df_Inventario.columns
# Out:
# Index(['FECHA_REM', 'NUM_REMITO', 'NUM_RECEP', 'N_DESPACHO', 'PAIS',
#        'ID_CARPETA', 'Articulo TTI ', 'Descripcion', 'DEPÓSITO', 'CANTIDAD',
#        'PRECIO UN', 'TOTAL', 'DIF', 'FACTURA'],
#       dtype='object')

# %%
df_Inventario.head()
# Out:
#    FECHA_REM      NUM_REMITO  NUM_RECEP        N_DESPACHO   PAIS   ID_CARPETA  \
# 0 2025-08-28   0IC040176600Y     1208.0  25001IC04176600Y  CHINA  100000839.0
# 1 2025-08-28   0IC040176600Y     1208.0  25001IC04176600Y  CHINA  100000839.0
# 2 2025-08-28   0IC040176600Y     1208.0  25001IC04176600Y  CHINA  100000839.0
# 3 2025-08-28   0IC040176600Y     1208.0  25001IC04176600Y  CHINA  100000839.0
# 4 2025-08-28   0IC040176600Y     1208.0  25001IC04176600Y  CHINA  100000839.0
#
#   Articulo TTI            Descripcion  DEPÓSITO  CANTIDAD  PRECIO UN   TOTAL  \
# 0    48324413ZA     1IN IMPCT BIT PH3       2.0     600.0       0.33   198.0
# 1    48324462ZA  2IN POWER IMPACT BIT       2.0    1200.0       0.30   360.0
# 2  MCX 48324487   2IN POWER IMPACT BI       2.0     600.0       0.29   174.0
# 3  MCX 48324712       1 IN INSERT BIT       2.0     640.0       2.50  1600.0
# 4    48324791ZA       3.5IN POWER BIT       2.0      26.0       8.25   214.5
#
#    DIF   FACTURA
# ...

# %%
df['Descripcion'] = df['Descripcion'].str.strip().str.upper()
df_Inventario['Descripcion'] = df_Inventario['Descripcion'].str.strip().str.upper()

# %% [markdown]
# ## INVENTARIO

# %%
df_Inventario.shape
# Out:
# (36, 14)

# %%
df_Inventario = (
    df_Inventario.groupby('Articulo TTI ', as_index=False)['CANTIDAD']
    .sum()
)

# %%
Ingresos = pd.merge(
    df,
    df_Inventario[['Articulo TTI ', 'CANTIDAD']],  # solo las columnas necesarias
    on="Articulo TTI ",  # columna común en ambos archivos
    how="left"
)

# %%
Ingresos.head()
# Out:
#   Articulo Solaut    Articulo TTI                               Descripcion  \
# 0             1000        ACW 1000                        ESCOBILLAS 6X6X15
# 1             1001        ACW 1001  ESCOBILLAS 8,8X10X16 (PRECIO POR UNIDAD
# 2             1002        ACW 1002                      ESCOBILLAS 8,X14X20
# 3             8080  MCX 4932367168     4932430148 MECHA BROCA UNIDRE 4 X 85
# 4             8087   MCX 493239939      4932430157 MECHA BROCA UNIDRE 7X100
#
#    Valor Fob U$S  Costo Standard  Unitario en $  \
# 0       0.760000                     1539.00000
# 1       1.480000                     2997.00000
# 2       2.010000                     4070.25000
# 3       0.937637                     1898.71397
# 4       1.078786                     2184.54188
#
#    Stock Inicial 26/04   CON AJUSTES INVENTARIO    INGRESOS TTI  SOLAUT  \
# 0                                           160.0           NaN     NaN
# ...

# %%
df_con_valor = Ingresos[Ingresos['CANTIDAD'].notna()]

# %%
df_con_valor.shape
# Out:
# (26, 11)

# %%
total = df_con_valor['CANTIDAD'].sum()

# %%
total
# Out:
# np.float64(17143.0)

# %%
Ingresos = Ingresos.rename(columns={"CANTIDAD":"INGRESOS MENSUAL"})

# %%
Ingresos.head()
# Out:
#   Articulo Solaut    Articulo TTI                               Descripcion  \
# 0             1000        ACW 1000                        ESCOBILLAS 6X6X15
# 1             1001        ACW 1001  ESCOBILLAS 8,8X10X16 (PRECIO POR UNIDAD
# 2             1002        ACW 1002                      ESCOBILLAS 8,X14X20
# 3             8080  MCX 4932367168     4932430148 MECHA BROCA UNIDRE 4 X 85
# 4             8087   MCX 493239939      4932430157 MECHA BROCA UNIDRE 7X100
#
#    Valor Fob U$S  Costo Standard  Unitario en $  \
# 0       0.760000                     1539.00000
# 1       1.480000                     2997.00000
# 2       2.010000                     4070.25000
# 3       0.937637                     1898.71397
# 4       1.078786                     2184.54188
#
#    Stock Inicial 26/04   CON AJUSTES INVENTARIO    INGRESOS TTI  SOLAUT  \
# 0                                           160.0           NaN     NaN
# ...

# %%
Ingresos.columns
# Out:
# Index(['Articulo Solaut ', 'Articulo TTI ', 'Descripcion', 'Valor Fob U$S',
#        'Costo Standard  Unitario en $',
#        'Stock Inicial 26/04   CON AJUSTES INVENTARIO  ', 'INGRESOS TTI',
#        'SOLAUT', 'SERVICIO TECNICO', 'BONIFICACION', 'INGRESOS MENSUAL'],
#       dtype='object')

# %%
Ingresos['Articulo Solaut '] = Ingresos['Articulo Solaut '].astype(str).str.strip().str.upper()

# %% [markdown]
# ## SOLAUT

# %%
df_solaut = pd.read_excel("/content/Solaut.xlsx")

# %%
dfsolaut = pd.read_excel("/content/Inventario TTI - python.xlsx")

# %%
#df_solaut['Articulo Solaut '] = df_solaut['Articulo Solaut '].astype(str).str.strip()#

# %%
#df_final['Articulo TTI '] = df_final['Articulo TTI '].astype(str).str.strip()#

# %%
#df_final['Articulo TTI '] = df_final['Articulo TTI '].str.lower()#

# %%
#df_solaut['Articulo Solaut '] = df_solaut['Articulo Solaut '].str.lower()#

# %%
df_solaut.head()
# Out:
#         Fecha    Código                              Cliente          Factura  \
# 0  27/08/2025   34082.0  BRIATORE S.A                         0099-A-00013840
# 1  27/08/2025   34082.0  BRIATORE S.A                         0099-A-00013840
# 2  27/08/2025  100215.0  DARIO JAVIER MARTINEZ                0095-A-00024158
# 3  27/08/2025  100215.0  DARIO JAVIER MARTINEZ                0095-A-00024158
# 4  27/08/2025  100215.0  DARIO JAVIER MARTINEZ                0095-A-00024158
#
#        Articulo Solaut                                   Artículo  \
# 0              48228311  BOLSO ESTRUCTURADO PACKOUT DE 10"
# 1  3697259A              (EX2997-259 A)COMBO 2904-20 Y 2953-20
# 2              48270811  MECHA PALETA 13/16 - 21MM
# 3              48270621  MECHA PALETA 5/8 - 16MM.
# 4              48270871  MECHA PALETA 7/8 - 22MM
#
#              Familia  Cant.  Precio L.  Desc. 1  ...  Desc. C. Desc. P.  Tasa  \
# ...

# %%
df_solaut['Articulo Solaut '] = df_solaut['Articulo Solaut '].astype(str).str.strip().str.upper()

# %%
dfsolaut['Articulo Solaut '] = dfsolaut['Articulo Solaut '].astype(str).str.strip().str.upper()

# %%
df_solaut.columns
# Out:
# Index(['Fecha', 'Código', 'Cliente', 'Factura', 'Articulo Solaut ', 'Artículo',
#        'Familia', 'Cant.', 'Precio L.', 'Desc. 1', 'Desc. 2', 'Desc. 3',
#        'Desc. 4', 'Desc. 5', 'Desc. C.', 'Desc. P.', 'Tasa', 'Iva 10',
#        'Iva 21', 'Neto', 'Total', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
dfsolautsum = (
    df_solaut.groupby('Articulo Solaut ', as_index=False)['Cant.']
    .sum()
)

# %%
df_solautsum_filtrado = dfsolautsum[dfsolautsum['Cant.'] != 0]

# %%
df_final = pd.merge(
    dfsolaut,
    df_solautsum_filtrado[['Articulo Solaut ', 'Cant.']],  # solo las columnas necesarias
    on="Articulo Solaut ",  # columna común en ambos archivos
    how="left"
)

# %%
df_final.head()
# Out:
#   Articulo Solaut    Articulo TTI                                 Descripcion  \
# 0             1000        ACW 1000   ESCOBILLAS 6X6X15
# 1             1001        ACW 1001    ESCOBILLAS 8,8X10X16 (PRECIO POR UNIDAD
# 2             1002        ACW 1002                        ESCOBILLAS 8,X14X20
# 3             8080  MCX 4932367168   4932430148 MECHA BROCA UNIDRE 4 X 85
# 4             8087   MCX 493239939   4932430157 MECHA BROCA UNIDRE 7X100
#
#    Valor Fob U$S  Costo Standard  Unitario en $  \
# 0       0.760000                     1539.00000
# 1       1.480000                     2997.00000
# 2       2.010000                     4070.25000
# 3       0.937637                     1898.71397
# 4       1.078786                     2184.54188
#
#    Stock Inicial 26/04   CON AJUSTES INVENTARIO    INGRESOS TTI  SOLAUT  \
# 0                                           160.0           NaN     NaN
# 1                                           175.0           NaN     NaN
# ...

# %%
df_con_valorsolaut = df_final[df_final['Cant.'] != 0]

# %%
total = df_con_valorsolaut['Cant.'].sum()

# %%
total
# Out:
# np.float64(30620.0)

# %% [markdown]
# ## BONIFICACIONES

# %%
df_bonificaciones = pd.read_excel("/content/Bonificaciones.xlsx")

# %%
dfboni = pd.read_excel("/content/Inventario TTI - python.xlsx")

# %%
df_bonificaciones.columns
# Out:
# Index(['Fecha', 'Código', 'Cliente', 'Articulo Solaut ',
#        'Cantidad bonificaciones', 'BOCA', 'LETRA', 'FACT', 'OBSERVACION'],
#       dtype='object')

# %%
df_bonificaciones.head()
# Out:
#         Fecha  Código                              Cliente Articulo Solaut   \
# 0  27/08/2025   37678  SIBONA LORENA ELVIA                         48228435
# 1  27/08/2025   37678  SIBONA LORENA ELVIA                         48228429
# 2  27/08/2025   37678  SIBONA LORENA ELVIA                         48228424
# 3  27/08/2025   37678  SIBONA LORENA ELVIA                         48228430
# 4  27/08/2025   37678  SIBONA LORENA ELVIA                         48228427
#
#    Cantidad bonificaciones  BOCA LETRA  FACT OBSERVACION
# 0                        4   111     A   313       bonif
# 1                        1   111     A   313       bonif
# 2                        2   111     A   313       bonif
# 3                        2   111     A   313       bonif
# 4                        2   111     A   313       bonif

# %%
df_bonificaciones.shape
# Out:
# (353, 9)

# %%
dfboni.columns
# Out:
# Index(['Articulo Solaut ', 'Articulo TTI ', 'Descripcion', 'Valor Fob U$S',
#        'Costo Standard  Unitario en $',
#        'Stock Inicial 26/04   CON AJUSTES INVENTARIO  ', 'INGRESOS TTI',
#        'SOLAUT', 'SERVICIO TECNICO', 'BONIFICACION'],
#       dtype='object')

# %%
df_bonificaciones['Articulo Solaut '] = df_bonificaciones['Articulo Solaut '].astype(str).str.strip().str.upper()

# %%
dfboni['Articulo Solaut '] = dfboni['Articulo Solaut '].astype(str).str.strip().str.upper()

# %%
dfboni.columns
# Out:
# Index(['Articulo Solaut ', 'Articulo TTI ', 'Descripcion', 'Valor Fob U$S',
#        'Costo Standard  Unitario en $',
#        'Stock Inicial 26/04   CON AJUSTES INVENTARIO  ', 'INGRESOS TTI',
#        'SOLAUT', 'SERVICIO TECNICO', 'BONIFICACION'],
#       dtype='object')

# %%
df_bonisum = (
    df_bonificaciones.groupby('Articulo Solaut ', as_index=False)['Cantidad bonificaciones']
    .sum()
)

# %%
df_bonisum_filtrado = df_bonisum[df_bonisum['Cantidad bonificaciones'] != 0]

# %%
Bonificaciones = pd.merge(
    dfboni,
    df_bonisum_filtrado[['Articulo Solaut ', 'Cantidad bonificaciones']],  # solo las columnas necesarias
    on="Articulo Solaut ",  # columna común en ambos archivos
    how="left"
)

# %%
Bonificaciones.head()
# Out:
#   Articulo Solaut    Articulo TTI                                 Descripcion  \
# 0             1000        ACW 1000   ESCOBILLAS 6X6X15
# 1             1001        ACW 1001    ESCOBILLAS 8,8X10X16 (PRECIO POR UNIDAD
# 2             1002        ACW 1002                        ESCOBILLAS 8,X14X20
# 3             8080  MCX 4932367168   4932430148 MECHA BROCA UNIDRE 4 X 85
# 4             8087   MCX 493239939   4932430157 MECHA BROCA UNIDRE 7X100
#
#    Valor Fob U$S  Costo Standard  Unitario en $  \
# 0       0.760000                     1539.00000
# 1       1.480000                     2997.00000
# 2       2.010000                     4070.25000
# 3       0.937637                     1898.71397
# 4       1.078786                     2184.54188
#
#    Stock Inicial 26/04   CON AJUSTES INVENTARIO    INGRESOS TTI  SOLAUT  \
# 0                                           160.0           NaN     NaN
# 1                                           175.0           NaN     NaN
# ...

# %%
df_con_valorboni = Bonificaciones[Bonificaciones['Cantidad bonificaciones'] != 0]

# %%
total = df_con_valorboni['Cantidad bonificaciones'].sum()

# %%
total
# Out:
# np.float64(-201.0)

# %% [markdown]
# ##SERVICIO TECNICO

# %%
df_serviciotecnico = pd.read_excel("/content/Servicio tecnico.xlsx")

# %%
dfserv = pd.read_excel("/content/Inventario TTI - python.xlsx")

# %%
dfserv.shape
# Out:
# (2112, 10)

# %%
df_serviciotecnico.columns
# Out:
# Index(['Fecha', 'Código', 'Cliente', 'Articulo Solaut ',
#        'Cantidad servicio tecnico', 'BOCA', 'LETRA', 'FACT', 'OBSERVACION'],
#       dtype='object')

# %%
dfserv['Articulo Solaut '] = dfserv['Articulo Solaut '].astype(str).str.strip().str.upper()

# %%
df_serviciotecnico['Articulo Solaut '] = df_serviciotecnico['Articulo Solaut '].astype(str).str.strip().str.upper()

# %%
df_serviciotecnico.shape
# Out:
# (88, 9)

# %%
#df_serviciotecnicosum['Articulo Solaut '] = df_serviciotecnico['Articulo Solaut '].astype(str).str.strip().str.upper()#

# %%
df_serviciotecnicosum = (
    df_serviciotecnico.groupby('Articulo Solaut ', as_index=False)['Cantidad servicio tecnico']
    .sum()
)

# %%
df_serviciotecnicosum.shape
# Out:
# (50, 2)

# %%
df_serviciotecnicosum_filtrado = df_serviciotecnicosum[df_serviciotecnicosum['Cantidad servicio tecnico'] != 0]

# %%
Servicio = pd.merge(
    dfserv,
    df_serviciotecnicosum_filtrado[['Articulo Solaut ', 'Cantidad servicio tecnico']],
    on='Articulo Solaut ',
    how='left'
)

# %%
Servicio.shape
# Out:
# (2112, 11)

# %%
df_con_valorserv = Servicio[Servicio['Cantidad servicio tecnico'] != 0]

# %%
total = df_con_valorserv['Cantidad servicio tecnico'].sum()

# %%
total
# Out:
# np.float64(-91.0)

# %% [markdown]
# ##UNION DE COLUMNAS

# %%
df1 = df_con_valorsolaut[['Articulo Solaut ', 'Cant.']]

# %%
df1["Cant."].sum()
# Out:
# np.float64(30620.0)

# %%
df2 = df_con_valorboni[['Articulo Solaut ', 'Cantidad bonificaciones']]

# %%
df2["Cantidad bonificaciones"].sum()
# Out:
# np.float64(-201.0)

# %%
df3 = df_con_valorserv[['Articulo Solaut ', 'Cantidad servicio tecnico']]

# %%
df3.shape
# Out:
# (2112, 2)

# %%
df2.shape
# Out:
# (2112, 2)

# %%
df1.shape
# Out:
# (2112, 2)

# %%
Ingresos.shape
# Out:
# (2112, 11)

# %%
df3["Cantidad servicio tecnico"].sum()
# Out:
# np.float64(-91.0)

# %%
df_invetariotti = (
    Ingresos
    .merge(df1, on='Articulo Solaut ', how='left')
)

# %%
df_invetariotti.head()
# Out:
#   Articulo Solaut    Articulo TTI                               Descripcion  \
# 0             1000        ACW 1000                        ESCOBILLAS 6X6X15
# 1             1001        ACW 1001  ESCOBILLAS 8,8X10X16 (PRECIO POR UNIDAD
# 2             1002        ACW 1002                      ESCOBILLAS 8,X14X20
# 3             8080  MCX 4932367168     4932430148 MECHA BROCA UNIDRE 4 X 85
# 4             8087   MCX 493239939      4932430157 MECHA BROCA UNIDRE 7X100
#
#    Valor Fob U$S  Costo Standard  Unitario en $  \
# 0       0.760000                     1539.00000
# 1       1.480000                     2997.00000
# 2       2.010000                     4070.25000
# 3       0.937637                     1898.71397
# 4       1.078786                     2184.54188
#
#    Stock Inicial 26/04   CON AJUSTES INVENTARIO    INGRESOS TTI  SOLAUT  \
# 0                                           160.0           NaN     NaN
# ...

# %%
df_invetariotti = (
    df_invetariotti
    .merge(df2, on='Articulo Solaut ', how='left')
)

# %%
df_invetariotti = (
    df_invetariotti
    .merge(df3, on='Articulo Solaut ', how='left')
)

# %%
df_invetariotti.head()
# Out:
#   Articulo Solaut    Articulo TTI                               Descripcion  \
# 0             1000        ACW 1000                        ESCOBILLAS 6X6X15
# 1             1001        ACW 1001  ESCOBILLAS 8,8X10X16 (PRECIO POR UNIDAD
# 2             1002        ACW 1002                      ESCOBILLAS 8,X14X20
# 3             8080  MCX 4932367168     4932430148 MECHA BROCA UNIDRE 4 X 85
# 4             8087   MCX 493239939      4932430157 MECHA BROCA UNIDRE 7X100
#
#    Valor Fob U$S  Costo Standard  Unitario en $  \
# 0       0.760000                     1539.00000
# 1       1.480000                     2997.00000
# 2       2.010000                     4070.25000
# 3       0.937637                     1898.71397
# 4       1.078786                     2184.54188
#
#    Stock Inicial 26/04   CON AJUSTES INVENTARIO    INGRESOS TTI  SOLAUT  \
# 0                                           160.0           NaN     NaN
# ...

# %%
df_invetariotti.shape
# Out:
# (2112, 14)

# %% [markdown]
# ## Creacion de calculos

# %%
df_invetariotti.columns
# Out:
# Index(['Articulo Solaut ', 'Articulo TTI ', 'Descripcion', 'Valor Fob U$S',
#        'Costo Standard  Unitario en $',
#        'Stock Inicial 26/04   CON AJUSTES INVENTARIO  ', 'INGRESOS TTI',
#        'SOLAUT', 'SERVICIO TECNICO', 'BONIFICACION', 'INGRESOS MENSUAL',
#        'Cant.', 'Cantidad bonificaciones', 'Cantidad servicio tecnico'],
#       dtype='object')

# %%
df_invetariotti["Stock al 27/09/2025"] = (
    df_invetariotti["Stock Inicial 26/04   CON AJUSTES INVENTARIO  "] +
    df_invetariotti["INGRESOS TTI"] +
    df_invetariotti["Cant."] +
    df_invetariotti["Cantidad bonificaciones"] +
    df_invetariotti["Cantidad servicio tecnico"]
)

# %%
df_invetariotti["Stock al 27/09/2025"] = (
    df_invetariotti[[
        "Stock Inicial 26/04   CON AJUSTES INVENTARIO  ",
        "INGRESOS TTI",
        "Cant.",
        "Cantidad bonificaciones",
        "Cantidad servicio tecnico"
    ]]
    .fillna(0)
    .sum(axis=1)
)

# %%
df_invetariotti["Stock al 27/09/2025"].sum()
# Out:
# np.float64(249618.0)

# %%
df_invetariotti.to_excel('df_invetariottifina.xlsx', index=False)
